# %%
# %matplotlib inline
import matplotlib as plt
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.tools import mpl_to_plotly
import plotly.graph_objects as go

# %%
calls = pd.read_csv(r"C:/Users/btros/Detroit-911-Calls-Dash-App/notebooks/raw_csvs/call_grid_with_weather.csv")
holidays = pd.read_csv(r"C:/Users/btros/Detroit-911-Calls-Dash-App/notebooks/raw_csvs/holidays.csv")
calls_raw = pd.read_csv(r"C:/Users/btross/OneDrive/Documents/LSDS-Unit-2-Project/911_Calls_For_Service.csv")
holidays = holidays.drop(columns='Unnamed: 0')
calls = calls.drop(columns='Unnamed: 0')

# %%
merged = pd.merge(calls, holidays, how='left', on=
                  ['year', 'month', 'day'])

# %%
merged = merged.drop(columns='Unnamed: 0')

# %%
merged['is_holiday'] = merged['is_holiday'].replace(np.NaN, 0)
merged
# Out:
#         year  month  day  dow  week  part_of_day  lat_grid  lon_grid  count  \
# 0       2016      9   20    1    38            1       5.0       3.0      1
# 1       2016      9   20    1    38            1       5.0       4.0      1
# 2       2016      9   20    1    38            1       5.0       9.0      1
# 3       2016      9   20    1    38            1       7.0       3.0      1
# 4       2016      9   20    1    38            1       7.0      11.0      1
# ...      ...    ...  ...  ...   ...          ...       ...       ...    ...
# 392107  2019     11   14    3    46            4       9.0       9.0      1
# 392108  2019     11   14    3    46            4       9.0      10.0      3
# 392109  2019     11   14    3    46            4       9.0      11.0      4
# 392110  2019     11   14    3    46            4       9.0      12.0     16
# 392111  2019     11   14    3    46            4       9.0      13.0      2
#
# ...

# %%
px.density_heatmap(merged, x='lon_grid', y='lat_grid')
